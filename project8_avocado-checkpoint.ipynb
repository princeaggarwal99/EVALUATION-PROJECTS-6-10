# %%
# IMPORTING LIBRARIES   ##  TASK 1
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings 
warnings.filterwarnings('ignore')

# %%
# IMPORTING DATASET
df=pd.read_csv('avacado.csv')

# %%
df.shape
# Out:
# (1517, 14)

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1           1  20-12-2015          1.35      54876.98   674.28   44638.81
# 2           2  13-12-2015          0.93     118220.22   794.70  109149.67
# 3           3  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4           4  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
#REMOVING IRRELEVANT INDEX COLUMNS
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1  20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2  13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3  06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4  29-11-2015          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
# NO NULL VALUES 
df.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
sns.heatmap(df.isnull()) # HEATMAP OF NULL VALUES # 0

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags         year
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  1517.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074  2015.162821
# ...

# %%
df.corr() #CORRELATION OF THE DATASET
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.111597   -0.097682   -0.177480    -0.048284  0.178683
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1517 entries, 0 to 1516
# Data columns (total 13 columns):
# Date            1517 non-null object
# AveragePrice    1517 non-null float64
# Total Volume    1517 non-null float64
# 4046            1517 non-null float64
# 4225            1517 non-null float64
# 4770            1517 non-null float64
# Total Bags      1517 non-null float64
# Small Bags      1517 non-null float64
# Large Bags      1517 non-null float64
# XLarge Bags     1517 non-null float64
# type            1517 non-null object
# year            1517 non-null int64
# region          1517 non-null object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 154.2+ KB

# %%
df.dtypes # DATATYPES PRESENT IN THE DATA ARE
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %%
df['Date']=pd.to_datetime(df['Date'])
# CONVERTING THE COLUMN TO DATE TIME FROM OBJECT

# %%
# EXTRACTING DAY , MONTH , YEAR FROM THE DATETIME DATE FEATURE
df_dates=pd.DataFrame()
df_dates['month']=df['Date'].dt.month_name()
df_dates['year']=df['Date'].dt.year
df_dates['day']=df['Date'].dt.day_name()
df_dates
# Out:
#           month  year        day
# 0      December  2015     Sunday
# 1      December  2015     Sunday
# 2      December  2015     Sunday
# 3          June  2015     Friday
# 4      November  2015     Sunday
# ...         ...   ...        ...
# 1512    October  2016     Sunday
# 1513  September  2016   Saturday
# 1514   February  2016  Wednesday
# 1515  September  2016     Sunday
# 1516  September  2016     Sunday
#
# [1517 rows x 3 columns]

# %%
df_dates['year'].drop_duplicates() # 2YEARS ON ONLY
# Out:
# 0       2015
# 1270    2016
# Name: year, dtype: int64

# %%
df_dates['type_of_day']=np.where((df_dates["day"]=="sunday")|(df_dates["day"]=="saturday"),"weekend","weekday")
df_dates 
# TTYPE OF DAY WHETHER WEEKDAY OR NOT
# Out:
#           month  year        day type_of_day
# 0      December  2015     Sunday     weekday
# 1      December  2015     Sunday     weekday
# 2      December  2015     Sunday     weekday
# 3          June  2015     Friday     weekday
# 4      November  2015     Sunday     weekday
# ...         ...   ...        ...         ...
# 1512    October  2016     Sunday     weekday
# 1513  September  2016   Saturday     weekday
# 1514   February  2016  Wednesday     weekday
# 1515  September  2016     Sunday     weekday
# 1516  September  2016     Sunday     weekday
#
# [1517 rows x 4 columns]

# %%
df_dates['type_of_day'].nunique()
# ONLY WEEKDAYS , NO WEEKENDS
# Out:
# 1

# %%
df.skew()
#SKEWNESS OF DATASET
# Out:
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# year            1.828332
# dtype: float64

# %%
# REMOVING SKEWNESS FROM DATASET 
df['Total Volume']=np.log1p(df['Total Volume']+1000)
df['4046']=np.log1p(df['4046']+1000)
df['4225']=np.log1p(df['4225']+1000)
df['4770']=np.log1p(df['4770']+100)
df['Total Bags']=np.log1p(df['Total Bags']+1000)
df['Small Bags']=np.log1p(df['Small Bags']+1000)
df['Large Bags']=np.log1p(df['Large Bags']+100)
df['XLarge Bags']=np.log1p(df['XLarge Bags'])

# %%
df.skew() #ALMOST REMOVED
# Out:
# AveragePrice   -0.109444
# Total Volume    0.674340
# 4046            0.017577
# 4225            0.249772
# 4770           -0.052991
# Total Bags      0.748522
# Small Bags      0.767160
# Large Bags     -0.011495
# XLarge Bags     0.783913
# year            1.828332
# dtype: float64

# %%
plt.figure(figsize=(13,7))
sns.heatmap(df.corr(),annot=True)
# CORRELATION DATASET HEATMAP

# %%
df.corr() # CORRELATION OF DATASET
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.326550 -0.515684 -0.132199 -0.277548
# Total Volume     -0.326550      1.000000  0.777497  0.894790  0.658735
# 4046             -0.515684      0.777497  1.000000  0.474112  0.593939
# 4225             -0.132199      0.894790  0.474112  1.000000  0.575534
# 4770             -0.277548      0.658735  0.593939  0.575534  1.000000
# Total Bags       -0.189536      0.939238  0.667193  0.850168  0.612706
# Small Bags       -0.148725      0.925114  0.631328  0.857761  0.628787
# Large Bags       -0.250374      0.672162  0.614443  0.519298  0.387183
# XLarge Bags      -0.064988      0.430375  0.329060  0.386451  0.590381
# year              0.178683      0.003553 -0.125492  0.011370  0.027059
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      year
# AveragePrice   -0.189536   -0.148725   -0.250374    -0.064988  0.178683
# ...

# %%
sns.boxplot(x='year',y='AveragePrice',data=df)
#AVERAGE PRICE DURING YEAR
#GREATER IN 2016

# %%
sns.pairplot(df,x_vars=['Small Bags','Large Bags','XLarge Bags'],y_vars='AveragePrice',size=7,aspect=0.7,kind='reg')

# %%
df['type'].unique()
# Out:
# array(['conventional'], dtype=object)

# %%
sns.catplot(x='type',y='AveragePrice',data=df)

# %%
sns.distplot(df['AveragePrice'])

# %%
sns.distplot(df['Total Volume'])

# %%
sns.factorplot('AveragePrice','region',data=df, hue='year', size=8,aspect=0.7,join=False,)

# %%
sns.pairplot(df,x_vars=['Total Volume','Total Bags'],y_vars='AveragePrice',size=7,aspect=0.7,kind='reg')

# %%
df['region'].unique()
#REGIION OF AVOCADO
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'Columbus', 'DallasFtWorth', 'Denver', 'Detroit', 'GrandRapids',
#        'GreatLakes', 'HarrisburgScranton', 'HartfordSpringfield',
#        'Houston', 'Indianapolis', 'Jacksonville', 'LasVegas',
#        'LosAngeles', 'Louisville', 'MiamiFtLauderdale', 'Midsouth',
#        'Nashville', 'NewYork', 'Northeast', 'NorthernNewEngland',
#        'Orlando', 'Philadelphia', 'PhoenixTucson', 'Pittsburgh', 'Plains',
#        'Portland', 'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
sns.pairplot(df,x_vars=['4046','4225','4770'],y_vars='AveragePrice',size=7,aspect=0.7,kind='reg')

# %%
sns.pairplot(df,x_vars='year',y_vars='AveragePrice',size=7,aspect=0.7,kind='reg')

# %%
sns.barplot(x=df_dates['type_of_day'],y=df['AveragePrice'])

# %%
sns.barplot(x=df_dates['day'],y=df['AveragePrice'])
#AVERAGE PRICE DURING DAYS

# %%
sns.barplot(x=df_dates['month'],y=df['AveragePrice'])
#AVERAGE PRICE DURING MONTH

# %%
sns.barplot(x=df_dates['year'],y=df['AveragePrice'])
#AVERAGE PRICE DURING YEAR

# %%
df.plot(x='Date',y='AveragePrice',kind='line',figsize=(20,6))

# %%
avcado_ap=df.drop(['region','Date'],axis=1)
# DROPPING COLUMNS NOT HIGHLY CORR WITH DATASET

# %%
avcado_ap.head()
# Out:
#    AveragePrice  Total Volume      4046       4225      4770  Total Bags  \
# 0          1.33     11.085792  7.619597  10.923342  5.005020    9.179662
# 1          1.35     10.930926  7.423736  10.728536  5.070978    9.259755
# 2          0.93     11.688736  7.493150  11.609604  5.444580    9.121110
# 3          1.08     11.289696  7.665285  11.197905  5.156639    8.826465
# 4          1.28     10.859779  7.571721  10.710842  5.174906    8.879744
#
#    Small Bags  Large Bags  XLarge Bags          type  year
# 0    9.170000    5.269146          0.0  conventional  2015
# 1    9.250433    5.290739          0.0  conventional  2015
# 2    9.109769    5.318806          0.0  conventional  2015
# 3    8.806634    5.458564          0.0  conventional  2015
# 4    8.851844    5.699406          0.0  conventional  2015

# %%
avcado_ap=pd.get_dummies(avcado_ap)
#CONVERTING OBJECT DATA INTO FLOAT OR INT BY GETTING DUMMIES

# %%
avcado_ap.head()
# Out:
#    AveragePrice  Total Volume      4046       4225      4770  Total Bags  \
# 0          1.33     11.085792  7.619597  10.923342  5.005020    9.179662
# 1          1.35     10.930926  7.423736  10.728536  5.070978    9.259755
# 2          0.93     11.688736  7.493150  11.609604  5.444580    9.121110
# 3          1.08     11.289696  7.665285  11.197905  5.156639    8.826465
# 4          1.28     10.859779  7.571721  10.710842  5.174906    8.879744
#
#    Small Bags  Large Bags  XLarge Bags  year  type_conventional
# 0    9.170000    5.269146          0.0  2015                  1
# 1    9.250433    5.290739          0.0  2015                  1
# 2    9.109769    5.318806          0.0  2015                  1
# 3    8.806634    5.458564          0.0  2015                  1
# 4    8.851844    5.699406          0.0  2015                  1

# %%
# SEPERATING TARGET VARIBLE AND FEATURES
x=avcado_ap.iloc[:,1:11]
x.head()
# Out:
#    Total Volume      4046       4225      4770  Total Bags  Small Bags  \
# 0     11.085792  7.619597  10.923342  5.005020    9.179662    9.170000
# 1     10.930926  7.423736  10.728536  5.070978    9.259755    9.250433
# 2     11.688736  7.493150  11.609604  5.444580    9.121110    9.109769
# 3     11.289696  7.665285  11.197905  5.156639    8.826465    8.806634
# 4     10.859779  7.571721  10.710842  5.174906    8.879744    8.851844
#
#    Large Bags  XLarge Bags  year  type_conventional
# 0    5.269146          0.0  2015                  1
# 1    5.290739          0.0  2015                  1
# 2    5.318806          0.0  2015                  1
# 3    5.458564          0.0  2015                  1
# 4    5.699406          0.0  2015                  1

# %%
y=avcado_ap.iloc[:,0]
y.head() #TARGET VARIABLE
# Out:
# 0    1.33
# 1    1.35
# 2    0.93
# 3    1.08
# 4    1.28
# Name: AveragePrice, dtype: float64

# %%
# SCALING DATA 
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
x=ss.fit_transform(x)

# %%
x #DATA SCALED
# Out:
# array([[-1.35310988, -1.69047342, -0.58076466, ..., -0.81077519,
#         -0.44100815,  0.        ],
#        [-1.4612264 , -1.7800332 , -0.6972243 , ..., -0.81077519,
#         -0.44100815,  0.        ],
#        [-0.93217635, -1.74829255, -0.17050278, ..., -0.81077519,
#         -0.44100815,  0.        ],
#        ...,
#        [-0.64684852, -0.25190101, -0.59783903, ...,  1.10389091,
#          2.26753179,  0.        ],
#        [-0.60633083, -0.18264217, -0.59012211, ..., -0.81077519,
#          2.26753179,  0.        ],
#        [-0.62929795, -0.28438714, -0.58358957, ..., -0.81077519,
#          2.26753179,  0.        ]])

# %%
# IMPORTING  METRICS AND OTHER MODELS TO TRAIN AND TEST
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn import linear_model
from sklearn.metrics import mean_absolute_error
from sklearn import metrics 
from sklearn.linear_model import LogisticRegression,LinearRegression
from sklearn.metrics import  mean_squared_error, r2_score
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import GradientBoostingRegressor,AdaBoostRegressor,RandomForestRegressor

# %%
# CREATING A FUNCTION FOR FINDING OUT THE BEST RANDOM STATE HAVING THE MAX r SCORE 
def maxr2_Score(regr,x,y):
    max_r_score=0
    for r_state in range(42,101):
        x_train, x_test, y_train, y_test=train_test_split(x,y,random_state=r_state,test_size=0.22)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print('r2_score corr to random state',r_state,'is:',r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2 score corr to ",final_r_state,'is',max_r_score)       
    return final_r_state

# %%
# FINDING  BEST RANDOM STATE FOR LINEAR REG WITH HIGH R SCORE
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_Score(lreg,x,y)
# Out:
# r2_score corr to random state 42 is: 0.3746038493980475
# r2_score corr to random state 43 is: 0.4295854020491666
# r2_score corr to random state 44 is: 0.3597643169139799
# r2_score corr to random state 45 is: 0.3333410785844687
# r2_score corr to random state 46 is: 0.39252412646532675
# r2_score corr to random state 47 is: 0.4101082513699492
# r2_score corr to random state 48 is: 0.37926439322193006
# r2_score corr to random state 49 is: 0.34457902252187633
# r2_score corr to random state 50 is: 0.3146786904325626
# r2_score corr to random state 51 is: 0.4072253736374054
# r2_score corr to random state 52 is: 0.398890416586269
# r2_score corr to random state 53 is: 0.39337824670680654
# r2_score corr to random state 54 is: 0.40748429880289183
# r2_score corr to random state 55 is: 0.41230237502386813
# r2_score corr to random state 56 is: 0.22587878411784534
# r2_score corr to random state 57 is: 0.3591975356913062
# r2_score corr to random state 58 is: 0.3272525667048658
# ...

# %%
# IMPORTING PCA FOR FINDING BEST CORRELATED COLUMNS
from sklearn.decomposition import PCA
pca = PCA(n_components=8)

# %%
x_new=pca.fit_transform(x)

# %%
def maxr2_Score(regr,x_new,y):
    max_r_score=0
    for r_state in range(42,101):
        x_train, x_test, y_train, y_test=train_test_split(x_new,y,random_state=r_state,test_size=0.22)
        regr.fit(x_train,y_train)
        y_pred=regr.predict(x_test)
        r2_scr=r2_score(y_test,y_pred)
        print('r2_score corr to random state',r_state,'is:',r2_scr)
        if r2_scr>max_r_score:
            max_r_score=r2_scr
            final_r_state=r_state
    print()
    print()
    print("max r2 score corr to ",final_r_state,'is',max_r_score)       
    return final_r_state

# %%
from sklearn.linear_model import LinearRegression
lreg=LinearRegression()
r_state=maxr2_Score(lreg,x_new,y)
# Out:
# r2_score corr to random state 42 is: 0.3758848845999595
# r2_score corr to random state 43 is: 0.39812992011239945
# r2_score corr to random state 44 is: 0.31727340277869087
# r2_score corr to random state 45 is: 0.3086349513902559
# r2_score corr to random state 46 is: 0.3586735866768136
# r2_score corr to random state 47 is: 0.38675769029549634
# r2_score corr to random state 48 is: 0.36658650359913403
# r2_score corr to random state 49 is: 0.3398437904429351
# r2_score corr to random state 50 is: 0.308725953944864
# r2_score corr to random state 51 is: 0.38088986820012327
# r2_score corr to random state 52 is: 0.3807925192482251
# r2_score corr to random state 53 is: 0.372872999369799
# r2_score corr to random state 54 is: 0.3874067788338138
# r2_score corr to random state 55 is: 0.3790451945300195
# r2_score corr to random state 56 is: 0.24124647197892457
# r2_score corr to random state 57 is: 0.37046672953123605
# r2_score corr to random state 58 is: 0.29182840344322036
# ...

# %%
# ON usinG pca we are getting bad results as before using pca 
# therefore dropping the method of using the PCA

# %%
#random state max r2 score corr to  89 is 
x_train,x_test,y_train,y_test=train_test_split(x_new,y,random_state=89,test_size=0.22)
lr=LinearRegression()
lr.fit(x_train,y_train)
ylreg=lr.predict(x_test)
print(lr.score(x_test, y_test)*100)
print(mean_squared_error(ylreg, y_test))
print(mean_absolute_error(ylreg, y_test))
print(cross_val_score(lreg,x,y,cv=5,scoring="r2").mean())
print(r2_score(y_test,ylreg))
# Out:
# 42.27832859009555
# 0.019748316846861933
# 0.10962509340818419
# 0.1593103888522062
# 0.4227832859009555

# %%
# grid search CV = FINDING BEST PARAMETERS
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
knn=KNeighborsRegressor()

# %%
parameters={'n_neighbors':[i+1 for i in range(10)]}
clf=GridSearchCV(knn,parameters)
clf.fit(x,y)
clf.best_params_
# Out:
# C:\Users\prince\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'n_neighbors': 10}

# %%
#finding best rstate and rscore for knn 
r_state=maxr2_Score(knn,x,y)
# Out:
# r2_score corr to random state 42 is: 0.7792639029758122
# r2_score corr to random state 43 is: 0.8158242217150169
# r2_score corr to random state 44 is: 0.779300276775623
# r2_score corr to random state 45 is: 0.7569697343810144
# r2_score corr to random state 46 is: 0.7940474656742186
# r2_score corr to random state 47 is: 0.8003907196162225
# r2_score corr to random state 48 is: 0.7714954577357755
# r2_score corr to random state 49 is: 0.7812018696184626
# r2_score corr to random state 50 is: 0.7501685382197414
# r2_score corr to random state 51 is: 0.8103135572029128
# r2_score corr to random state 52 is: 0.8155456097541205
# r2_score corr to random state 53 is: 0.794228539432295
# r2_score corr to random state 54 is: 0.7879858798712274
# r2_score corr to random state 55 is: 0.7846880070760096
# r2_score corr to random state 56 is: 0.7458348621728793
# r2_score corr to random state 57 is: 0.806178607487645
# r2_score corr to random state 58 is: 0.7542840582802427
# ...

# %%
## KNN REGRESSOR
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=60,test_size=0.22)
knn=KNeighborsRegressor()
knn.fit(x_train,y_train)
knnpred=knn.predict(x_test)
print(knn.score(x_test, y_test))
print(mean_squared_error(knnpred, y_test))
print(mean_absolute_error(knnpred, y_test))
print(cross_val_score(knn,x,y,cv=5,scoring='r2'))
print(r2_score(knnpred,y_test))
# Out:
# 0.8300230185552374
# 0.00724222754491018
# 0.06512574850299402
# [-0.1680767  -0.24212613  0.29636942  0.1005736   0.23973356]
# 0.7657206935547705

# %%
## SVR FROM SUPPORT VECTOR MACHINE
from sklearn.svm import SVR
svr=SVR()
para_grid={'kernel':['poly','rbf']}
clf_svr=GridSearchCV(svr,para_grid)
clf_svr.fit(x,y)
clf_svr.best_params_
# Out:
# C:\Users\prince\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'kernel': 'rbf'}

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=60,test_size=0.22)
svr=SVR(kernel="rbf")
svr.fit(x_train,y_train)
y_svr=svr.predict(x_test)
print(svr.score(x_test,y_test))

print(mean_squared_error(y_svr, y_test))
print(mean_absolute_error(y_svr, y_test))
print(r2_score(y_svr, y_test))
print(cross_val_score(svr,x,y,cv=5,scoring='r2'))
# Out:
# 0.7691012886369869
# 0.009837926249213336
# 0.07854870256031252
# 0.6356422449118155
# [0.15084459 0.26493643 0.6243939  0.02647813 0.13221745]

# %%
## DECISION TREE REGRESSOR
dtr=DecisionTreeRegressor()
dtr.fit(x_train,y_train)
dtrpred=dtr.predict(x_test)

dtr.score(x_test,y_test)
print(r2_score(y_test,dtrpred))
# Out:
# 0.6822730783848825

# %%
r_state=maxr2_Score(dtr,x,y)
# Out:
# r2_score corr to random state 42 is: 0.6711316568083288
# r2_score corr to random state 43 is: 0.7096863389269952
# r2_score corr to random state 44 is: 0.6257060963783214
# r2_score corr to random state 45 is: 0.6078675453216441
# r2_score corr to random state 46 is: 0.6451717693401009
# r2_score corr to random state 47 is: 0.7168821435171266
# r2_score corr to random state 48 is: 0.5568469139838326
# r2_score corr to random state 49 is: 0.6848232949153373
# r2_score corr to random state 50 is: 0.6607830876422975
# r2_score corr to random state 51 is: 0.66515557405539
# r2_score corr to random state 52 is: 0.7503707705954926
# r2_score corr to random state 53 is: 0.6153258873754366
# r2_score corr to random state 54 is: 0.5781336697054748
# r2_score corr to random state 55 is: 0.6497891376906587
# r2_score corr to random state 56 is: 0.4676763360378813
# r2_score corr to random state 57 is: 0.6724406720827527
# r2_score corr to random state 58 is: 0.5213541163339557
# ...

# %%
score=cross_val_score(dtr,x,y,cv=10,scoring='r2')
score
# Out:
# array([-2.59420408,  0.06410335, -1.19100818, -0.40911958, -2.05666804,
#         0.5826813 , -0.46680911, -0.49787196, -1.99252309, -0.50705757])

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr= GradientBoostingRegressor()
parameters={'n_estimators':[1,10,50,100,200,300,400,500,1000],'learning_rate':[0.001,0.01,0.1,1]}
clfg=GridSearchCV(gbr,parameters)
clfg.fit(x,y)
clfg.best_params_
# Out:
# C:\Users\prince\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'learning_rate': 0.01, 'n_estimators': 200}

# %%
r_state=maxr2_Score(gbr,x,y)
# Out:
# r2_score corr to random state 42 is: 0.7182996920893535
# r2_score corr to random state 43 is: 0.7457526366726043
# r2_score corr to random state 44 is: 0.6954087135702691
# r2_score corr to random state 45 is: 0.6624430417379363
# r2_score corr to random state 46 is: 0.7428343003135238
# r2_score corr to random state 47 is: 0.7232064143069146
# r2_score corr to random state 48 is: 0.7145935485796315
# r2_score corr to random state 49 is: 0.7030964907083496
# r2_score corr to random state 50 is: 0.7014906689243918
# r2_score corr to random state 51 is: 0.7314206704067956
# r2_score corr to random state 52 is: 0.7354073807489072
# r2_score corr to random state 53 is: 0.7367343841108395
# r2_score corr to random state 54 is: 0.7039037805775982
# r2_score corr to random state 55 is: 0.6980879948689924
# r2_score corr to random state 56 is: 0.6503150982181631
# r2_score corr to random state 57 is: 0.7048254187657403
# r2_score corr to random state 58 is: 0.7265039487566446
# ...

# %%
## GRADIENT BOOSTING TECHNIQUE
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=47,test_size=0.22)
gbr=GradientBoostingRegressor(learning_rate= 0.01, n_estimators=200)
gbr.fit(x_train,y_train)
y_gbr=gbr.predict(x_test)
print(gbr.score(x_test,y_test))
print(mean_squared_error(y_gbr, y_test))
print(mean_absolute_error(y_gbr, y_test))
print(r2_score(y_gbr, y_test))
print(cross_val_score(gbr,x,y,cv=5,scoring='r2').mean())
# Out:
# 0.6246440786782699
# 0.013706882771078524
# 0.09361529000426717
# 0.0711056892039067
# 0.35163798953249403

# %%
# RANDOM FORESST REGRESSOR
from sklearn.ensemble import RandomForestRegressor
rfr=RandomForestRegressor()
parameters={'n_estimators':[1,10,50,100,200,300,400,500,1000]}
clfr=GridSearchCV(rfr,parameters)
clfr.fit(x,y)
clfr.best_params_
# Out:
# {'n_estimators': 400}

# %%
rfr = RandomForestRegressor(n_estimators = 400)
r_state=maxr2_Score(rfr,x,y)
# Out:
# r2_score corr to random state 42 is: 0.8774533126312513
# r2_score corr to random state 43 is: 0.9038795573889418
# r2_score corr to random state 44 is: 0.902551299469179
# r2_score corr to random state 45 is: 0.8557082251283552
# r2_score corr to random state 46 is: 0.870651575704724
# r2_score corr to random state 47 is: 0.8807488855058015
# r2_score corr to random state 48 is: 0.8779945649690021
# r2_score corr to random state 49 is: 0.8668654237659381
# r2_score corr to random state 50 is: 0.8610440688638834
# r2_score corr to random state 51 is: 0.8736226951115336
# r2_score corr to random state 52 is: 0.8677350643010089
# r2_score corr to random state 53 is: 0.868369257873523
# r2_score corr to random state 54 is: 0.8750561663351398
# r2_score corr to random state 55 is: 0.8152692006509681
# r2_score corr to random state 56 is: 0.8655561537067581
# r2_score corr to random state 57 is: 0.888950505062018
# r2_score corr to random state 58 is: 0.8966175465790373
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=63,test_size=0.22)
rfr = RandomForestRegressor(n_estimators = 400)
rfr.fit(x_train,y_train)
yrfr=rfr.predict(x_test)
print(rfr.score(x_test,y_test))
print(r2_score(yrfr, y_test))
print(cross_val_score(rfr,x,y,cv=10,scoring='r2'))
print('MAE:', mean_absolute_error(y_test,yrfr))
print('MSE:', mean_squared_error(y_test,yrfr))
print('RMSE:', np.sqrt(mean_squared_error(y_test,yrfr)))
# Out:
# 0.9209285868916744
# 0.8999526297422864
# [-383.95579889  -70.58771346  -34.20416072  -11.42005224  -72.39448636
#   -65.78419925  -51.83478887 -436.28941565    0.46608863 -385.40826257]
# MAE: 2.5690419161676643
# MSE: 20.182014221556884
# RMSE: 4.492439673669184

# %%
## RANDOM FOREST IS WORKING BEST :-
plt.scatter(x=y_test,y=yrfr)
# MUCH LINEARITY IN THIS MODEL

# %%
plt.scatter(x=y_test,y=y_svr)

# %%
results = pd.DataFrame({'Y_Test':y_test , 'Predictions':yrfr},columns=['Y_Test','Predictions'])
results.head()
# Out:
#       Y_Test  Predictions
# 1142      46      40.3450
# 748       30      29.8900
# 138        3       4.5675
# 468       17      16.7000
# 975       39      34.3100

# %%
#CONCLUSION= RFR(RANDOM FOREST IS WORKING THE BEST) WITH A R SCORE OF GREATER THAN 92 AND MUCH LINEARITY

# %%
#NOW TASK 2 CLASSIFICATION TASK

# %%
df.head()
# Out:
#         Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0 2015-12-27          1.33     11.085792  7.619597  10.923342  5.005020
# 1 2015-12-20          1.35     10.930926  7.423736  10.728536  5.070978
# 2 2015-12-13          0.93     11.688736  7.493150  11.609604  5.444580
# 3 2015-06-12          1.08     11.289696  7.665285  11.197905  5.156639
# 4 2015-11-29          1.28     10.859779  7.571721  10.710842  5.174906
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0    9.179662    9.170000    5.269146          0.0  conventional  2015  Albany
# 1    9.259755    9.250433    5.290739          0.0  conventional  2015  Albany
# 2    9.121110    9.109769    5.318806          0.0  conventional  2015  Albany
# 3    8.826465    8.806634    5.458564          0.0  conventional  2015  Albany
# 4    8.879744    8.851844    5.699406          0.0  conventional  2015  Albany

# %%
df.dtypes
# Out:
# Date            datetime64[ns]
# AveragePrice           float64
# Total Volume           float64
# 4046                   float64
# 4225                   float64
# 4770                   float64
# Total Bags             float64
# Small Bags             float64
# Large Bags             float64
# XLarge Bags            float64
# type                    object
# year                     int64
# region                  object
# dtype: object

# %%
sns.lineplot(x='region',y='AveragePrice',data=df)

# %%
sns.factorplot('Total Volume','region',data=df, hue='year', size=8,aspect=0.7,join=False,)

# %%
sns.factorplot('Total Bags','region',data=df, hue='year', size=8,aspect=0.7,join=False,)

# %%
sns.factorplot('AveragePrice','region',data=df, hue='year', size=8,aspect=0.7,join=False,)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['region']=le.fit_transform(df['region'])

# %%
df.head()
# Out:
#         Date  AveragePrice  Total Volume      4046       4225      4770  \
# 0 2015-12-27          1.33     11.085792  7.619597  10.923342  5.005020
# 1 2015-12-20          1.35     10.930926  7.423736  10.728536  5.070978
# 2 2015-12-13          0.93     11.688736  7.493150  11.609604  5.444580
# 3 2015-06-12          1.08     11.289696  7.665285  11.197905  5.156639
# 4 2015-11-29          1.28     10.859779  7.571721  10.710842  5.174906
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0    9.179662    9.170000    5.269146          0.0  conventional  2015       0
# 1    9.259755    9.250433    5.290739          0.0  conventional  2015       0
# 2    9.121110    9.109769    5.318806          0.0  conventional  2015       0
# 3    8.826465    8.806634    5.458564          0.0  conventional  2015       0
# 4    8.879744    8.851844    5.699406          0.0  conventional  2015       0

# %%
df_new=pd.get_dummies(df)

# %%
df_new
# Out:
#            Date  AveragePrice  Total Volume       4046       4225      4770  \
# 0    2015-12-27          1.33     11.085792   7.619597  10.923342  5.005020
# 1    2015-12-20          1.35     10.930926   7.423736  10.728536  5.070978
# 2    2015-12-13          0.93     11.688736   7.493150  11.609604  5.444580
# 3    2015-06-12          1.08     11.289696   7.665285  11.197905  5.156639
# 4    2015-11-29          1.28     10.859779   7.571721  10.710842  5.174906
# ...         ...           ...           ...        ...        ...       ...
# 1512 2016-10-16          1.39     12.164454  10.977297  10.957236  9.777515
# 1513 2016-09-10          1.51     12.096463  10.699346  10.881637  9.879224
# 1514 2016-02-10          1.48     12.097439  10.765655  10.894781  9.731389
# 1515 2016-09-25          1.47     12.155477  10.917119  10.907690  9.775451
# 1516 2016-09-18          1.43     12.122579  10.694610  10.918617  9.721061
#
# ...

# %%
x=df_new.drop(['Date','year','region',],axis=1)

# %%
x
# Out:
#       AveragePrice  Total Volume       4046       4225      4770  Total Bags  \
# 0             1.33     11.085792   7.619597  10.923342  5.005020    9.179662
# 1             1.35     10.930926   7.423736  10.728536  5.070978    9.259755
# 2             0.93     11.688736   7.493150  11.609604  5.444580    9.121110
# 3             1.08     11.289696   7.665285  11.197905  5.156639    8.826465
# 4             1.28     10.859779   7.571721  10.710842  5.174906    8.879744
# ...            ...           ...        ...        ...       ...         ...
# 1512          1.39     12.164454  10.977297  10.957236  9.777515   11.009067
# 1513          1.51     12.096463  10.699346  10.881637  9.879224   11.071341
# 1514          1.48     12.097439  10.765655  10.894781  9.731389   11.057484
# 1515          1.47     12.155477  10.917119  10.907690  9.775451   11.081107
# 1516          1.43     12.122579  10.694610  10.918617  9.721061   11.157757
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()

# %%
x=ss.fit_transform(x)

# %%
x
# Out:
# array([[ 1.35048079, -1.35310988, -1.69047342, ..., -1.31142736,
#         -0.81077519,  0.        ],
#        [ 1.45639674, -1.4612264 , -1.7800332 , ..., -1.30243145,
#         -0.81077519,  0.        ],
#        [-0.76783831, -0.93217635, -1.74829255, ..., -1.29073811,
#         -0.81077519,  0.        ],
#        ...,
#        [ 2.14485045, -0.64684852, -0.25190101, ...,  0.25587425,
#          1.10389091,  0.        ],
#        [ 2.09189247, -0.60633083, -0.18264217, ...,  0.25687483,
#         -0.81077519,  0.        ],
#        [ 1.88006056, -0.62929795, -0.28438714, ...,  0.39770753,
#         -0.81077519,  0.        ]])

# %%
y=df_new['region']

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: region, dtype: int32

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier,AdaBoostClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB

# %%
knn=KNeighborsClassifier()
parameters={'n_neighbors':[i+1 for i in range(10)]}
clf=GridSearchCV(knn,parameters)
clf.fit(x,y)
clf.best_params_
# Out:
# C:\Users\prince\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'n_neighbors': 1}

# %%
rfc=RandomForestClassifier()
parameters={'n_estimators':[1,10,50,100,200,300,400,500,1000]}
clfr=GridSearchCV(rfr,parameters)
clfr.fit(x,y)
clfr.best_params_
# Out:
# C:\Users\prince\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# {'n_estimators': 50}

# %%
rfc=RandomForestClassifier()
knn=KNeighborsClassifier(n_neighbors=1)
svc=SVC()
ada=AdaBoostClassifier()
gbc=GradientBoostingClassifier()
dtc=DecisionTreeClassifier()

# %%
models = []
models.append(('randomforestclassifier', rfc))
models.append(('kneighborsclassifier', knn))
models.append(('svc', svc))
models.append(('ada boost classifier', ada))
models.append(('gradient boosting classifier', gbc))
models.append(('decisiontreeclassifier', dtc))

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=.22)
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,auc
from sklearn.model_selection import cross_val_score

# %%
Model=[]
score=[]
cvs=[]
rocscore=[]
for name,model in models:
    print('********',name,'*******')
    print('\n')
    Model.append(name)
    model.fit(x_train,y_train)
    print(model)
    pre=model.predict(x_test)
    print('\n')
    AS=accuracy_score(y_test,pre)
    print("acc_score=",AS)
    score.append(AS*100)
    print('\n')
    sc=cross_val_score(model,x,y,cv=10,scoring='accuracy').mean()
    print('cross_val_sc=',sc)
    cvs.append(sc*100)
    print('\n')
    fpr,tpr,thresholds=roc_curve(y_test,pre,pos_label=2)
    roc_auc=auc(fpr,tpr)
    print("roc_auc_sc=",roc_auc)
    rocscore.append(roc_auc*100)
    print('\n')
    print('classification_repo\n',classification_report(y_test,pre))
    print('\n')
    cm=confusion_matrix(y_test,pre)
    print(cm)
    print('\n')
    plt.figure(figsize=(10,40))
    plt.subplot(911)
    plt.title(name)
    print(sns.heatmap(cm,annot=True))
    plt.subplot(912)
    plt.title(name)
    plt.plot(fpr,tpr)
    plt.plot([0,1],[0,1],'r--')
    plt.xlabel('TPR')
    plt.ylabel('FPR')
    print('\n\n')
# Out:
# ******** randomforestclassifier *******
#
#
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)
#
#
# acc_score= 0.9341317365269461
#
#
# cross_val_sc= 0.9197219937551475
#
#
# roc_auc_sc= 0.07608695652173914
#
#
# classification_repo
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        11
#            1       1.00      0.87      0.93        15
#            2       0.92      1.00      0.96        12
#            3       1.00      1.00      1.00        12
# ...

# %%
result=pd.DataFrame({'model':Model,'Accu_score':score,'cross_val_Score':cvs})

# %%
result
# Out:
#                           model  Accu_score  cross_val_Score
# 0        randomforestclassifier   93.413174        91.972199
# 1          kneighborsclassifier   95.209581        95.174456
# 2                           svc   89.820359        91.412112
# 3          ada boost classifier    7.485030         8.009336
# 4  gradient boosting classifier   90.419162        87.790274
# 5        decisiontreeclassifier   85.628743        83.945469

# %%
# CONCLUSION=  KNN CLASSIFIER IS WORKING BEST IN THE DATASET : WITH ABOVE RESULTS
